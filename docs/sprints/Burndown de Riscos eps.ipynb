# %%
risk1 = [12,12,8,8,12]
risk2 = [25,25,20,25,25]
risk3 = [9,9,6,6,12]
risk4 = [8,8,12,8,4]
risk5 = [20,20,8,12,4]
risk6 = [3,9,6,3,12]
risk7 = [12,12,6,3,3]
risk8 = [5,5,10,10,15]
risk9 = [15,15,15,12,6]
risk10 = [4,4,20,20,16]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Release 1

# %%
fig, ax = plt.subplots()
x=[1,2,3,4,5]
y=[risk1, risk2, risk3, risk4,risk5,risk6,risk7,risk8,risk9,risk10]
labels = ['Equipe Improdutiva', 'Descomprometimento de algum membro da gerência','Falhas na Comunicação', 'Alta dificuldade nos tópicos de desenvolvimento',
         'Escopo Nebuloso', 'Metodologias Ineficientes', 'Baixo Entrosamento da Equipe', 'Membros Desmotivados', 'Equipe Inexperiente com as Tecnologias',
         'Problemas de Ambiente']
pal = sns.color_palette()

ax.stackplot(x,y,labels=labels,colors=pal,alpha=0.7)
ax.set_xlabel('Sprint')
ax.set_ylabel('Peso')
ax.set_xlim=([0,5])
ax.set_xticks(x)
plt.grid(b=True, which='major', color='#666666', linestyle='-')

box = ax.get_position()
ax.legend(loc='center left', bbox_to_anchor=(1.05, 0.5))
plt.show()
